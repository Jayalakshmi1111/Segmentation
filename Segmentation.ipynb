# %%
# !pip install -q git+https://github.com/tensorflow/examples.git
# Out:
#   Building wheel for tensorflow-examples (setup.py) ... done
#   WARNING: Built wheel for tensorflow-examples is invalid: Metadata 1.2 mandates PEP 440 version, but 'f0cedeb322c0d0a508e58d923bacab10f806cc1d-' is not
#     Running setup.py install for tensorflow-examples ... done
#   DEPRECATION: tensorflow-examples was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import cv2
from scipy import io
import tensorflow_datasets as tfds
from tensorflow_examples.models.pix2pix import pix2pix
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/bearpaw/clothing-co-parsing.git
# Out:
# Cloning into 'clothing-co-parsing'...
# remote: Enumerating objects: 4234, done.
# remote: Total 4234 (delta 0), reused 0 (delta 0), pack-reused 4234
# Receiving objects: 100% (4234/4234), 124.59 MiB | 42.85 MiB/s, done.
# Resolving deltas: 100% (1100/1100), done.

# %%
# !echo $PWD
# Out:
# /content

# %%
# !ls clothing-co-parsing/
# Out:
# annotations  label_list.mat  photos	show_image_anno.m
# example.jpg  LICENSE	     README.md	show_pixel_anno.m

# %%
images = []
for i in range(1,1001):
    url = './clothing-co-parsing/photos/%04d.jpg'%(i)
    img = cv2.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    images.append(tf.convert_to_tensor(img))

# %%
masks = []
for i in range(1,1001):
    url = './clothing-co-parsing/annotations/pixel-level/%04d.mat'%(i)
    file = io.loadmat(url)
    mask = tf.convert_to_tensor(file['groundtruth'])
    masks.append(mask)

# %%
len(images), len(masks)
# Out:
# (1000, 1000)

# %%
plt.figure(figsize=(10,4))
for i in range(1,4):
    plt.subplot(1,3,i)
    img = images[i]
    plt.imshow(img, cmap='jet')
    plt.colorbar()
    plt.axis('off')
plt.show()

# %%
masks[0].numpy().min(), masks[0].numpy().max()
# Out:
# (0, 55)

# %%
plt.figure(figsize=(10,4))
for i in range(1,4):
    plt.subplot(1,3,i)
    img = masks[i]
    plt.imshow(img, cmap='jet')
    plt.colorbar()
    plt.axis('off')
plt.show()

# %%
base = keras.applications.DenseNet121(input_shape=[128,128,3], 
                                      include_top=False, 
                                      weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
len(base.layers)
# Out:
# 427

# %%
keras.utils.plot_model(base, show_shapes=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.693966 to fit

# %%
skip_names = ['conv1/relu', # size 64*64
             'pool2_relu',  # size 32*32
             'pool3_relu',  # size 16*16
             'pool4_relu',  # size 8*8
             'relu'        # size 4*4
             ]

# %%
skip_outputs = [base.get_layer(name).output for name in skip_names]
for i in range(len(skip_outputs)):
    print(skip_outputs[i])
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='conv1/relu/Relu:0', description="created by layer 'conv1/relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 256), dtype=tf.float32, name=None), name='pool2_relu/Relu:0', description="created by layer 'pool2_relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 512), dtype=tf.float32, name=None), name='pool3_relu/Relu:0', description="created by layer 'pool3_relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1024), dtype=tf.float32, name=None), name='pool4_relu/Relu:0', description="created by layer 'pool4_relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 1024), dtype=tf.float32, name=None), name='relu/Relu:0', description="created by layer 'relu'")

# %%
downstack = keras.Model(inputs=base.input,
                       outputs=skip_outputs)
downstack.trainable = False

# %%
# Four upstack layers for upsampling sizes 
# 4->8, 8->16, 16->32, 32->64 
upstack = [pix2pix.upsample(512,3),
          pix2pix.upsample(256,3),
          pix2pix.upsample(128,3),
          pix2pix.upsample(64,3)]

# %%
upstack[0].layers
# Out:
# [<keras.layers.convolutional.Conv2DTranspose at 0x7f86dc2076d0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f86dcfa1790>,
#  <keras.layers.advanced_activations.ReLU at 0x7f86db929a50>]

# %%
# define the input layer
inputs = keras.layers.Input(shape=[128,128,3])

# downsample 
down = downstack(inputs)
out = down[-1]

# prepare skip-connections
skips = reversed(down[:-1])
# choose the last layer at first 4 --> 8

# upsample with skip-connections
for up, skip in zip(upstack,skips):
    out = up(out)
    out = keras.layers.Concatenate()([out,skip])
    
# define the final transpose conv layer
# image 128 by 128 with 59 classes
out = keras.layers.Conv2DTranspose(59, 3,
                                  strides=2,
                                  padding='same',
                                  )(out)
# complete unet model
unet = keras.Model(inputs=inputs, outputs=out)

# %%
keras.utils.plot_model(unet, show_shapes=True)

# %%
def resize_image(image):
    image = tf.cast(image, tf.float32)
    image = image/255.0
    # resize image
    image = tf.image.resize(image, (128,128))
    return image

def resize_mask(mask):
    mask = tf.expand_dims(mask, axis=-1)
    mask = tf.image.resize(mask, (128,128))
    mask = tf.cast(mask, tf.uint8)
    return mask

# %%
X = [resize_image(i) for i in images]
y = [resize_mask(m) for m in masks]
len(X), len(y)
# Out:
# (1000, 1000)

# %%
images[0].dtype, masks[0].dtype, X[0].dtype, y[0].dtype
# Out:
# (tf.uint8, tf.uint8, tf.float32, tf.uint8)

# %%
plt.imshow(X[0])
plt.colorbar()
plt.show()

#plt.imshow(y[3], cmap='jet')
#plt.colorbar()
plt.show()

# %%
def brightness(img, mask):
    img = tf.image.adjust_brightness(img, 0.1)
    return img, mask

def gamma(img, mask):
    img = tf.image.adjust_gamma(img, 0.1)
    return img, mask

def hue(img, mask):
    img = tf.image.adjust_hue(img, -0.1)
    return img, mask

def crop(img, mask):
    img = tf.image.central_crop(img, 0.7)
    img = tf.image.resize(img, (128,128))
    mask = tf.image.central_crop(mask, 0.7)
    mask = tf.image.resize(mask, (128,128))
    mask = tf.cast(mask, tf.uint8)
    return img, mask

def flip_hori(img, mask):
    img = tf.image.flip_left_right(img)
    mask = tf.image.flip_left_right(mask)
    return img, mask

def flip_vert(img, mask):
    img = tf.image.flip_up_down(img)
    mask = tf.image.flip_up_down(mask)
    return img, mask

def rotate(img, mask):
    img = tf.image.rot90(img)
    mask = tf.image.rot90(mask)
    return img, mask

# %%
from sklearn.model_selection import train_test_split

train_X, val_X,train_y, val_y = train_test_split(X,y, 
                                                      test_size=0.2, 
                                                      random_state=0
                                                     )
train_X = tf.data.Dataset.from_tensor_slices(train_X)
val_X = tf.data.Dataset.from_tensor_slices(val_X)

train_y = tf.data.Dataset.from_tensor_slices(train_y)
val_y = tf.data.Dataset.from_tensor_slices(val_y)

train_X.element_spec, train_y.element_spec, val_X.element_spec, val_y.element_spec
# Out:
# (TensorSpec(shape=(128, 128, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(128, 128, 1), dtype=tf.uint8, name=None),
#  TensorSpec(shape=(128, 128, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(128, 128, 1), dtype=tf.uint8, name=None))

# %%
train = tf.data.Dataset.zip((train_X, train_y))
val = tf.data.Dataset.zip((val_X, val_y))

# perform augmentation on train data only

a = train.map(brightness)
b = train.map(gamma)
c = train.map(hue)
d = train.map(crop)
e = train.map(flip_hori)
f = train.map(flip_vert)
g = train.map(rotate)

train = train.concatenate(a)
train = train.concatenate(b)
train = train.concatenate(c)
train = train.concatenate(d)
train = train.concatenate(e)
train = train.concatenate(f)
train = train.concatenate(g)

# %%
BATCH = 64
AT = tf.data.AUTOTUNE
BUFFER = 1000

STEPS_PER_EPOCH = 800//BATCH
VALIDATION_STEPS = 200//BATCH

# %%
train = train.cache().shuffle(BUFFER).batch(BATCH).repeat()
train = train.prefetch(buffer_size=AT)
val = val.batch(BATCH)

# %%
example = next(iter(train))
preds = unet(example[0])
plt.imshow(example[0][60])
plt.colorbar()
plt.show()

# %%
pred_mask = tf.argmax(preds, axis=-1)
pred_mask = tf.expand_dims(pred_mask, -1)

# %%
unet.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            optimizer=keras.optimizers.RMSprop(lr=0.001),
            metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
hist = unet.fit(train,
               validation_data=val,
               steps_per_epoch=STEPS_PER_EPOCH,
               validation_steps=VALIDATION_STEPS,
               epochs=30)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 194s 15s/step - loss: 2.7912 - accuracy: 0.6076 - val_loss: 3.5158 - val_accuracy: 0.0720
# Epoch 2/30
# 12/12 [==============================] - 170s 14s/step - loss: 1.6315 - accuracy: 0.7675 - val_loss: 2.8437 - val_accuracy: 0.6674
# Epoch 3/30
# 12/12 [==============================] - 170s 14s/step - loss: 1.2333 - accuracy: 0.7779 - val_loss: 2.1472 - val_accuracy: 0.7560
# Epoch 4/30
# 12/12 [==============================] - 170s 14s/step - loss: 1.2857 - accuracy: 0.7223 - val_loss: 1.6921 - val_accuracy: 0.7700
# Epoch 5/30
# 12/12 [==============================] - 172s 14s/step - loss: 1.1569 - accuracy: 0.7362 - val_loss: 1.3295 - val_accuracy: 0.7957
# Epoch 6/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.9814 - accuracy: 0.7698 - val_loss: 1.0890 - val_accuracy: 0.7915
# Epoch 7/30
# 12/12 [==============================] - 170s 14s/step - loss: 0.8903 - accuracy: 0.7859 - val_loss: 1.0086 - val_accuracy: 0.7935
# Epoch 8/30
# 12/12 [==============================] - 170s 14s/step - loss: 0.8493 - accuracy: 0.7892 - val_loss: 0.9535 - val_accuracy: 0.7872
# Epoch 9/30
# 12/12 [==============================] - 173s 15s/step - loss: 0.7402 - accuracy: 0.8101 - val_loss: 0.8706 - val_accuracy: 0.8012
# Epoch 10/30
# 12/12 [==============================] - 172s 15s/step - loss: 0.7185 - accuracy: 0.8144 - val_loss: 0.8321 - val_accuracy: 0.7945
# Epoch 11/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.6930 - accuracy: 0.8193 - val_loss: 0.7871 - val_accuracy: 0.8032
# Epoch 12/30
# 12/12 [==============================] - 172s 15s/step - loss: 0.8192 - accuracy: 0.7915 - val_loss: 0.7467 - val_accuracy: 0.8105
# Epoch 13/30
# 12/12 [==============================] - 172s 15s/step - loss: 0.9224 - accuracy: 0.7663 - val_loss: 0.7569 - val_accuracy: 0.8085
# Epoch 14/30
# 12/12 [==============================] - 173s 15s/step - loss: 0.7916 - accuracy: 0.7985 - val_loss: 0.7564 - val_accuracy: 0.8051
# Epoch 15/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.7278 - accuracy: 0.8131 - val_loss: 0.7329 - val_accuracy: 0.8134
# Epoch 16/30
# 12/12 [==============================] - 172s 15s/step - loss: 0.6987 - accuracy: 0.8165 - val_loss: 0.7085 - val_accuracy: 0.8168
# Epoch 17/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.6655 - accuracy: 0.8245 - val_loss: 0.7031 - val_accuracy: 0.8194
# Epoch 18/30
# 12/12 [==============================] - 172s 14s/step - loss: 0.5729 - accuracy: 0.8460 - val_loss: 0.6790 - val_accuracy: 0.8233
# Epoch 19/30
# 12/12 [==============================] - 172s 15s/step - loss: 0.5982 - accuracy: 0.8384 - val_loss: 0.6839 - val_accuracy: 0.8240
# Epoch 20/30
# 12/12 [==============================] - 173s 15s/step - loss: 0.6161 - accuracy: 0.8362 - val_loss: 0.6939 - val_accuracy: 0.8192
# Epoch 21/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.8462 - accuracy: 0.7842 - val_loss: 0.6677 - val_accuracy: 0.8262
# Epoch 22/30
# 12/12 [==============================] - 172s 14s/step - loss: 0.7131 - accuracy: 0.8121 - val_loss: 0.6571 - val_accuracy: 0.8277
# Epoch 23/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.6260 - accuracy: 0.8347 - val_loss: 0.6415 - val_accuracy: 0.8325
# Epoch 24/30
# 12/12 [==============================] - 172s 15s/step - loss: 0.6376 - accuracy: 0.8310 - val_loss: 0.6146 - val_accuracy: 0.8373
# Epoch 25/30
# 12/12 [==============================] - 172s 15s/step - loss: 0.6181 - accuracy: 0.8346 - val_loss: 0.6290 - val_accuracy: 0.8338
# Epoch 26/30
# 12/12 [==============================] - 173s 15s/step - loss: 0.4775 - accuracy: 0.8690 - val_loss: 0.6319 - val_accuracy: 0.8331
# Epoch 27/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.5266 - accuracy: 0.8553 - val_loss: 0.6500 - val_accuracy: 0.8268
# Epoch 28/30
# 12/12 [==============================] - 172s 14s/step - loss: 0.5051 - accuracy: 0.8615 - val_loss: 0.5974 - val_accuracy: 0.8397
# Epoch 29/30
# 12/12 [==============================] - 171s 14s/step - loss: 0.6963 - accuracy: 0.8211 - val_loss: 0.5945 - val_accuracy: 0.8434
# Epoch 30/30
# 12/12 [==============================] - 172s 14s/step - loss: 0.6926 - accuracy: 0.8191 - val_loss: 0.5882 - val_accuracy: 0.8432

# %%
img, mask = next(iter(val))
pred = unet.predict(img)
plt.figure(figsize=(10,5))
for i in pred:
    plt.subplot(121)
    i = tf.argmax(i, axis=-1)
    plt.imshow(i,cmap='jet')
    plt.axis('off')
    plt.title('Prediction')
    break
plt.subplot(122)
#plt.imshow(mask[0], cmap='jet')
#plt.imshow(mask[0])
plt.axis('off')
#plt.title('Ground Truth')
plt.show()

# %%
history = hist.history
acc=history['accuracy']
val_acc = history['val_accuracy']

plt.plot(acc, '-', label='Training Accuracy')
plt.plot(val_acc, '--', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
